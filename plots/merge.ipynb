# %%
import pandas as pd


df1 = pd.read_csv("data/per1.csv")
df2 = pd.read_csv("data/per2.csv")

# %%
df = df1.merge(df2, how="outer")

# %%
df.to_csv("data/per.csv")

# %%
df1
# Out:
#        Relative Time (Process)  default-8-b - _step  default-8-b - _step__MIN  \
# 0                           11                  0.0                       0.0
# 1                           18                  1.0                       1.0
# 2                           20                  NaN                       NaN
# 3                           21                  NaN                       NaN
# 4                           25                  2.0                       2.0
# ...                        ...                  ...                       ...
# 94459                   527654                  NaN                       NaN
# 94460                   527665                  NaN                       NaN
# 94461                   527723                  NaN                       NaN
# 94462                   527734                  NaN                       NaN
# 94463                   527741                  NaN                       NaN
#
# ...

# %%
df2
# Out:
#        Relative Time (Process)  default-1-f - _step  default-1-f - _step__MIN  \
# 0                           14                  NaN                       NaN
# 1                           18                  NaN                       NaN
# 2                           29                  NaN                       NaN
# 3                           31                  NaN                       NaN
# 4                           35                  NaN                       NaN
# ...                        ...                  ...                       ...
# 92020                   599629                  NaN                       NaN
# 92021                   599673                  NaN                       NaN
# 92022                   599698                  NaN                       NaN
# 92023                   599719                  NaN                       NaN
# 92024                   599806                  NaN                       NaN
#
# ...

# %%
df
# Out:
#         Relative Time (Process)  default-8-b - _step  \
# 0                            11                  0.0
# 1                            18                  1.0
# 2                            20                  NaN
# 3                            21                  NaN
# 4                            25                  2.0
# ...                         ...                  ...
# 167540                   599629                  NaN
# 167541                   599673                  NaN
# 167542                   599698                  NaN
# 167543                   599719                  NaN
# 167544                   599806                  NaN
#
#         default-8-b - _step__MIN  default-8-b - _step__MAX  \
# 0                            0.0                       0.0
# 1                            1.0                       1.0
# 2                            NaN                       NaN
# 3                            NaN                       NaN
# ...
